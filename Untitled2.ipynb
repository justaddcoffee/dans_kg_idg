# %%
import grape
# Out:
# /Users/jtr4v/PythonProject/dans_kg_idg/venv/lib/python3.11/site-packages/ensmallen/__init__.py:22: UserWarning: Ensmallen is compiled for the Intel Haswell architecture (2013).On the current machine, the flags '['avx2', 'bmi2', 'popcnt']' are required but '{'avx2', 'bmi2'}' are not available.
# The library will use a slower but more compatible version (Intel Core2 2006).
#   warnings.warn(

# %%
import grape
import pandas as pd
pd.set_option('display.max_rows', None)
df = grape.get_models_dataframe()
df
# Out:
#                               model_name              task_name  \
# 0                      Walklets SkipGram         Node Embedding
# 1                      Walklets SkipGram         Node Embedding
# 2                     Degree-based SPINE         Node Embedding
# 3                          DeepWalk CBOW         Node Embedding
# 4                   Structured Embedding         Node Embedding
# 5                   Structured Embedding         Node Embedding
# 6                 Node-label-based SPINE         Node Embedding
# 7                       First-order LINE         Node Embedding
# 8                       First-order LINE         Node Embedding
# 9                      Second-order LINE         Node Embedding
# 10                     Second-order LINE         Node Embedding
# 11                                 RUINE         Node Embedding
# 12                   Laplacian Eigenmaps         Node Embedding
# 13                   Laplacian Eigenmaps         Node Embedding
# ...

# %%
t = df.groupby("task_name").agg('count').loc[:, ['available']]
t
# Out:
#                        available
# task_name
# Edge Embedding                 1
# Edge Label Prediction         16
# Edge Prediction               21
# Edge-label Prediction          2
# Node Embedding                78
# Node Label Prediction         20
